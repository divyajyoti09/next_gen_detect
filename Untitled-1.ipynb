# %%
import sys
sys.path.append('/home/divyajyoti/ACADEMIC/Projects/Cardiff_University/Next_gen_detectability/scripts/next_gen_detect')
from detector_psds import generate_psd
# Out:
# /home/divyajyoti/miniconda3/envs/igwn-py311/lib/python3.11/site-packages/pycbc/types/array.py:36: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   import lal as _lal

# %%
o5c = generate_psd('O5c', 102400, 0.1, 10)
et = generate_psd('ET10_CoBA', 102400, 0.1, 10)
ce20 = generate_psd('CE20', 102400, 0.1, 10)
# Out:
# WARNING:root:Requested number of samples exceeds the highest available frequency in the input data, will use max available frequency instead. (requested 10239.900000 Hz, available 7000.000000 Hz)
# WARNING:root:Requested number of samples exceeds the highest available frequency in the input data, will use max available frequency instead. (requested 10239.900000 Hz, available 10000.000000 Hz)
# WARNING:root:Requested number of samples exceeds the highest available frequency in the input data, will use max available frequency instead. (requested 10239.900000 Hz, available 5000.000000 Hz)

# %%
import pylab as plt
plt.loglog(o5c.sample_frequencies, o5c)
plt.loglog(et.sample_frequencies, et)
plt.loglog(ce20.sample_frequencies, ce20)

# %%
lst = ['O5', 'ET']
lst.remove('O5')
lst.extend(['O5a', 'O5b'])
lst
# Out:
# ['ET', 'O5a', 'O5b']
